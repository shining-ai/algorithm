# %%
import matplotlib.pyplot as plt
import random
import time

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                highlight_bars(arr, [j, j+1])
                time.sleep(0.1)

def plot_bars(arr):
    plt.clf()
    plt.bar(range(len(arr)), arr, color='b')
    plt.pause(0.01)

def highlight_bars(arr, indices):
    plt.clf()
    colors = ['r' if i in indices else 'b' for i in range(len(arr))]
    plt.bar(range(len(arr)), arr, color=colors)
    for i, val in enumerate(arr):
        plt.text(i, val, str(val), ha='center', va='bottom')
    plt.pause(0.01)

if __name__ == "__main__":
    arr = [random.randint(1, 100) for _ in range(20)]
    plt.ion()
    plot_bars(arr)
    bubble_sort(arr)
    plt.ioff()
    plt.show()

# %%
import matplotlib.pyplot as plt
import random
import time


def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        swapped = False
        for j in range(0, n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                plot_bars(arr, [j, j + 1], swapped=True)
                swapped = True
                time.sleep(0.1)
        if not swapped:
            # 既にソート済みの場合、ソートを終了
            break


def plot_bars(arr, highlight_indices=None, swapped=False):
    plt.clf()
    # colors = ['g' if i in highlight_indices else 'r' if swapped else 'b' for i in range(len(arr))]
    colors = ["r" if i in arr else "b" for i in range(len(arr))]
    plt.bar(range(len(arr)), arr, color=colors)
    for i, val in enumerate(arr):
        plt.text(i, val, str(val), ha="center", va="bottom")
    plt.pause(0.01)


if __name__ == "__main__":
    arr = [random.randint(1, 100) for _ in range(20)]
    plt.ion()
    plot_bars(arr)
    bubble_sort(arr)
    plt.ioff()
    plt.show()
